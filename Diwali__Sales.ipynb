# %%
# import python libraries

import numpy as np #numerical computing
import pandas as pd #data manipulation
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns # visualizing data

# %%
# import csv file
# DataFrame
df = pd.read_csv("C:\\Users\\HP\\Downloads\\Python_Diwali_Sales_Analysis-main\\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
df.shape #number of rows and columns
# Out:
# (11251, 15)

# %%
df.head()  #display the first 5 rows of a DataFrame
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info() #display the summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
# ['Status', 'unnamed1'] → these two columns will be removed
# axis=1 → axis=1 means we are dropping columns (axis=0 would mean rows)
# inplace=True → changes will be applied directly to the DataFrame (no new DataFrame will be created)

df.drop(['Status', 'unnamed1'], axis=1, inplace= True)

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
#change data type
df['Amount']= df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
# display all the column names
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# generate statistical summary of the numerical columns
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age','Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Gender**

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# *The dataset contains more Females (7832) than males (3407)*

# %%
# plotting a bar chart for gender vs total amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

ax = sns.barplot(x = 'Gender', y = 'Amount', data= sales_gen)

for bars in ax.containers:
    ax.bar_label(bars)
    
plt.show()

# %% [markdown]
# *The total purchase amount by Females is higher than that of Males.*

# %% [markdown]
# **Age**

# %%
age_order = df['Age Group'].value_counts().sort_values(ascending=False).index
ax = sns.countplot(data = df, x = 'Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# *The chart shows that the **26-35 age group** has the highest number of customers, while the **0-17 age group** has the lowest. Across most age groups, Females outnumber Males.*

# %%
#Total amount by Age group
Sales_age = df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(x = 'Age Group', y = 'Amount', data = Sales_age)
plt.show()

# %% [markdown]
# *Adults aged 26–35 years contributed the highest total purchase amount, followed by the 36–45 age group.*

# %%
### Top 10 States by Total Number of Orders
Sales_states = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = Sales_states, x = 'State',y='Orders')
plt.show()

# %% [markdown]
# *Uttar Pradesh, Maharashtra, and Karnataka have the highest number of orders among all states.*

# %%
### Top 10 States by Total Number of Amount

Sales_states = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = Sales_states, x = 'State',y='Amount')
plt.show()

# %% [markdown]
# *Uttar Pradesh, Maharashtra, and Karnataka generated the highest sales amount among all states.*

# %% [markdown]
# **Marital Status**

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# *Unmarried customers are higher in number compared to married customers*

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x='Marital_Status', y='Amount', hue='Gender')
plt.show()
print(sales_state)
# Out:
#    Marital_Status Gender    Amount
# 0               0      F  43786646
# 2               1      F  30549207
# 1               0      M  18338738
# 3               1      M  13574538

# %% [markdown]
# Unmarried women contribute(43786646) the highest purchase amount compared to all other groups.

# %% [markdown]
# **Occupation**

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bar in ax.containers:
    ax.bar_label(bars)

plt.show()

# %% [markdown]
# *Most of the buyers are from IT, Healthcare, and Aviation sectors compared to other occupations.*

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')

plt.show()

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# **Product Category**

# %%
sns.set(rc={'figure.figsize':(20,8)})
ax = sns.countplot(data = df, y = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# *The majority of purchases are from Clothing & Apparel, Food, and Electronics & Gadgets categories compared to other product categories.*

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,7)})
sns.barplot(data = sales_state, x = 'Product_Category', y='Amount')
plt.show()

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category.*

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
plt.show()

# %% [markdown]
# *The top 10 products with the highest number of orders are mainly led by Product_ID P00265242, followed by P00110942 and P00237542.*

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))

df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar', ax=ax1)

plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# *• Females dominate in both number of customers and purchase amount.*
#
# *• The 26–35 age group contributes the highest orders and sales.*
#
# *• Uttar Pradesh, Maharashtra, and Karnataka are the top states in sales and orders.*
#
# *• Unmarried females generate the highest purchase amount.*
#
# *• Most buyers work in IT, Healthcare, and Aviation.*
#
# *• Clothing, Food, and Electronics are the top-selling product categories.*
#
# *• Product_ID P00265242 is the most ordered product.*
